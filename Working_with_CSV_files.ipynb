# %% [markdown]
# <a href="https://colab.research.google.com/github/rkmaccha/data_collection/blob/main/Working_with_CSV_files.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# # Data Domains:
#
# Kaggle : https://www.kaggle.com/ <br>
# UCI : https://archive.ics.uci.edu/ml/index.php <br>
# sklearn-datasets : https://scikit-learn.org/stable/modules/classes.html?highlight=datasets#module-sklearn.datasets

# %% [markdown]
# PANDAS DOCUMENTATION : https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html?highlight=read_csv

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv("/content/drive/MyDrive/MachineLearning_Journey/dataset/IRIS.csv")

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# ## Reading CSV from a URL

# %%
df = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data")
                
print(df.head())
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
df = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data", 
                 names = ['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm', 'Species'])
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
import requests
from io import StringIO

url="https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv"
headers = {"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv66:0) Gecko/20100001 Firefox/66.0"}
req = requests.get(url,headers = headers)
data = StringIO(req.text)

data = pd.read_csv(data)

# %%
data.head()
# Out:
#     Country  Region
# 0   Algeria  AFRICA
# 1    Angola  AFRICA
# 2     Benin  AFRICA
# 3  Botswana  AFRICA
# 4   Burkina  AFRICA

# %% [markdown]
# ## csv files
# ### -> tab separated <br>
# ### -> column names missing

# %%
movie_Data= pd.read_csv("/content/drive/MyDrive/MachineLearning_Journey/dataset/movie_titles_metadata.tsv.txt")
movie_Data.head()
# Out:
#   m0\t10 things i hate about you\t1999\t6.90\t62847\t['comedy' 'romance']
# 0  m1\t1492: conquest of paradise\t1992\t6.20\t10...
# 1  m2\t15 minutes\t2001\t6.10\t25854\t['action' '...
# 2  m3\t2001: a space odyssey\t1968\t8.40\t163227\...
# 3  m4\t48 hrs.\t1982\t6.90\t22289\t['action' 'com...
# 4  m5\tthe fifth element\t1997\t7.50\t133756\t['a...

# %%
movie_Data= pd.read_csv("/content/drive/MyDrive/MachineLearning_Journey/dataset/movie_titles_metadata.tsv.txt", 
                        sep="\t",names=['id','title','year','rating','votes','genre'],index_col="id")
movie_Data.head()
# Out:
#                          title  year  rating     votes  \
# id
# m0  10 things i hate about you  1999     6.9   62847.0
# m1  1492: conquest of paradise  1992     6.2   10421.0
# m2                  15 minutes  2001     6.1   25854.0
# m3       2001: a space odyssey  1968     8.4  163227.0
# m4                     48 hrs.  1982     6.9   22289.0
#
#                                              genre
# id
# m0                            ['comedy' 'romance']
# m1     ['adventure' 'biography' 'drama' 'history']
# m2           ['action' 'crime' 'drama' 'thriller']
# m3                ['adventure' 'mystery' 'sci-fi']
# m4  ['action' 'comedy' 'crime' 'drama' 'thriller']

# %%
movie_Data.shape
# Out:
# (617, 5)

# %% [markdown]
# ## Header issues

# %%
df= pd.read_csv("/content/drive/MyDrive/MachineLearning_Journey/dataset/untitled.csv")
df.head()
# Out:
#    Unnamed: 0   Unnamed: 1 Unnamed: 2              Unnamed: 3 Unnamed: 4  \
# 0           0  enrollee_id       city  city_development_index     gender
# 1           1        29725    city_40                   0.776       Male
# 2           2        11561    city_21                   0.624        NaN
# 3           3        33241   city_115                   0.789        NaN
# 4           4          666   city_162                   0.767       Male
#
#                 Unnamed: 5           Unnamed: 6       Unnamed: 7  \
# 0      relevent_experience  enrolled_university  education_level
# 1   No relevent experience        no_enrollment         Graduate
# 2   No relevent experience     Full time course         Graduate
# 3   No relevent experience                  NaN         Graduate
# 4  Has relevent experience        no_enrollment          Masters
#
#          Unnamed: 8  Unnamed: 9   Unnamed: 10     Unnamed: 11   Unnamed: 12  \
# ...

# %%
df= pd.read_csv("/content/drive/MyDrive/MachineLearning_Journey/dataset/untitled.csv", header=1)
df.head()
# Out:
#    0  enrollee_id      city  city_development_index gender  \
# 0  1        29725   city_40                   0.776   Male
# 1  2        11561   city_21                   0.624    NaN
# 2  3        33241  city_115                   0.789    NaN
# 3  4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0   No relevent experience       no_enrollment        Graduate
# 1   No relevent experience    Full time course        Graduate
# 2   No relevent experience                 NaN        Graduate
# 3  Has relevent experience       no_enrollment         Masters
#
#   major_discipline experience company_size    company_type last_new_job  \
# 0             STEM         15        50-99         Pvt Ltd           >4
# 1             STEM          5          NaN             NaN        never
# 2  Business Degree         <1          NaN         Pvt Ltd        never
# ...

# %%
df.drop('0', axis=1, inplace=True)
df.head()
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0        29725   city_40                   0.776   Male
# 1        11561   city_21                   0.624    NaN
# 2        33241  city_115                   0.789    NaN
# 3          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0   No relevent experience       no_enrollment        Graduate
# 1   No relevent experience    Full time course        Graduate
# 2   No relevent experience                 NaN        Graduate
# 3  Has relevent experience       no_enrollment         Masters
#
#   major_discipline experience company_size    company_type last_new_job  \
# 0             STEM         15        50-99         Pvt Ltd           >4
# 1             STEM          5          NaN             NaN        never
# 2  Business Degree         <1          NaN         Pvt Ltd        never
# 3             STEM        >20        50-99  Funded Startup            4
#
# ...

# %% [markdown]
# ## usecols -> Pandas

# %%
data = pd.read_csv("/content/drive/MyDrive/MachineLearning_Journey/dataset/train.csv")
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data = pd.read_csv("/content/drive/MyDrive/MachineLearning_Journey/dataset/train.csv", usecols=['Survived','Sex','Age'])
data.head()
# Out:
#    Survived     Sex   Age
# 0         0    male  22.0
# 1         1  female  38.0
# 2         1  female  26.0
# 3         1  female  35.0
# 4         0    male  35.0

# %% [markdown]
# other errors we face : <br>
# -> encoding    <br>
# -> error_bad_lines  <br>
# -> nrows   <br>
# https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html?highlight=read_csv

# %% [markdown]
# # Complete PANDAS tutorial (notebook available)

# %% [markdown]
# -> dtype parameters <br>
# -> handling data types <br>
# -> Convertors  <br>
# -> nan or null values <br>
# -> working with chunksize <br>
